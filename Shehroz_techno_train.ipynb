# %% [markdown]
# # MINI PROJECT

# %% [markdown]
# ## 1).Problem Statement

# %% [markdown]
# ## 2).Hypothesis Generation

# %% [markdown]
# Hypothesis: Items with higher weight tend to sell for a higher price.
# Test: Correlate Item_Weight with Item_MRP.
#
# Hypothesis: Products with low fat content sell more than those with high fat content.
# Test: Compare the mean sales of items with low fat content to those with high fat content.
#
# Hypothesis: Products with higher visibility sell more.
# Test: Correlate Item_Visibility with Item_Outlet_Sales.
#
# Hypothesis: Certain types of products sell better at certain types of outlets.
# Test: Compare the mean sales of each Item_Type across different Outlet_Type.
#
# Hypothesis: Stores established more recently tend to have higher sales.
# Test: Correlate Outlet_Establishment_Year with Item_Outlet_Sales.
#
# Hypothesis: The size of the outlet is correlated with the amount of sales.
# Test: Compare the mean sales of each Outlet_Size category.
#
# Hypothesis: Stores in different location types have different sales.
# Test: Compare the mean sales of each Outlet_Location_Type category.

# %% [markdown]
# ## Loading data in pandas

# %%
import pandas as pd
train = pd.read_csv("Train.csv")
train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# ## Analyzing the dataframe

# %%
train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# there are total 12 columns but there are 6 numeric columns

# %%
train.corr()
# Out:
# <ipython-input-7-0bc27f030cd9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train.corr()
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.014048  0.027141
# Item_Visibility              -0.014048         1.000000 -0.001315
# Item_MRP                      0.027141        -0.001315  1.000000
# Outlet_Establishment_Year    -0.011588        -0.074834  0.005020
# Item_Outlet_Sales             0.014123        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.011588           0.014123
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# ...

# %% [markdown]
# ## 5).Exploratory Data Analysis

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# Plot histograms or density plots
train[['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Outlet_Establishment_Year', 'Item_Outlet_Sales']].hist(figsize=(10, 8))
plt.tight_layout()
plt.show()

# Plot box plots
plt.figure(figsize=(10, 8))
sns.boxplot(data=train[['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Outlet_Establishment_Year', 'Item_Outlet_Sales']])
plt.tight_layout()
plt.show()

#A z score is a measure of a value and how far it is from a mean. The standard deviation is normalized. A z score with a value
#more than 3 is 3 STDVs away from the mean. That can be considered an outlier.

# Calculate z-scores and flag potential outliers
num_cols = ['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Outlet_Establishment_Year', 'Item_Outlet_Sales']
for col in num_cols:
    z = np.abs((train[col] - train[col].mean()) / train[col].std())
    train[col+'_zscore'] = z
    outliers = train[z > 3]
    print(f'{col}: {len(outliers)} potential outliers')
# Out:
# C:\Users\Shehroz\anaconda3\lib\site-packages\seaborn\categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# Item_Weight: 0 potential outliers
# Item_Visibility: 95 potential outliers
# Item_MRP: 0 potential outliers
# Outlet_Establishment_Year: 0 potential outliers
# Item_Outlet_Sales: 90 potential outliers

# %% [markdown]
# # Univariate Analysis.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train["Item_Weight"].hist(bins=20)
plt.title("Item Weight Distribution")
plt.xlabel("Item Weight")
plt.ylabel("Count")
plt.show()

# %%
train["Item_Fat_Content"].value_counts().plot(kind="bar")
plt.title("Item Fat Content Counts")
plt.xlabel("Item Fat Content")
plt.ylabel("Count")
plt.show()

# %%
train["Item_Visibility"].hist(bins=20)
plt.title("Item Visibility Distribution")
plt.xlabel("Item Visibility")
plt.ylabel("Count")
plt.show()

# %%
train["Item_Type"].value_counts().plot(kind="bar")
plt.title("Item Type Counts")
plt.xlabel("Item Type")
plt.ylabel("Count")
plt.show()

# %%
train["Item_MRP"].hist(bins=20)
plt.title("Item MRP Distribution")
plt.xlabel("Item MRP")
plt.ylabel("Count")
plt.show()

# %%
train["Outlet_Identifier"].value_counts().plot(kind="bar")
plt.title("Outlet Identifier Counts")
plt.xlabel("Outlet Identifier")
plt.ylabel("Count")
plt.show()

# %%
train["Outlet_Establishment_Year"].hist(bins=20)
plt.title("Outlet Establishment Year Distribution")
plt.xlabel("Outlet Establishment Year")
plt.ylabel("Count")
plt.show()

# %%
train["Outlet_Size"].value_counts().plot(kind="bar")
plt.title("Outlet Size Counts")
plt.xlabel("Outlet Size")
plt.ylabel("Count")
plt.show()

# %%
train["Outlet_Location_Type"].value_counts().plot(kind="bar")
plt.title("Outlet Location Type Counts")
plt.xlabel("Outlet Location Type")
plt.ylabel("Count")
plt.show()

# %%
train["Outlet_Type"].value_counts().plot(kind="bar")
plt.title("Outlet Type Counts")
plt.xlabel("Outlet Type")
plt.ylabel("Count")
plt.show()

# %%
sns.histplot(train["Item_Outlet_Sales"], kde=True)
plt.title("Item Outlet Sales Distribution")
plt.xlabel("Item Outlet Sales")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Bivariate Analysis.

# %%
sns.scatterplot(x="Item_MRP", y="Item_Outlet_Sales", data=train)
plt.title("Item MRP vs Outlet Sales")
plt.xlabel("Item MRP")
plt.ylabel("Outlet Sales")
plt.show()

# %%
sns.scatterplot(x="Item_Visibility", y="Item_Outlet_Sales", data=train)
plt.title("Item Visibility vs Outlet Sales")
plt.xlabel("Item Visibility")
plt.ylabel("Outlet Sales")
plt.show()

# %%
sns.scatterplot(x="Item_Weight", y="Item_Outlet_Sales", data=train)
plt.title("Item Weight vs Outlet Sales")
plt.xlabel("Item Weight")
plt.ylabel("Outlet Sales")
plt.show()

# %%
sns.boxplot(x="Item_Type", y="Item_Outlet_Sales", data=train)
plt.xticks(rotation=90)
plt.title("Item Type vs Outlet Sales")
plt.xlabel("Item Type")
plt.ylabel("Outlet Sales")
plt.show()

# %%
sns.boxplot(x="Item_Fat_Content", y="Item_Outlet_Sales", data=train)
plt.title("Item Fat Content vs Outlet Sales")
plt.xlabel("Item Fat Content")
plt.ylabel("Outlet Sales")
plt.show()

# %%
sns.boxplot(x="Outlet_Location_Type", y="Item_Outlet_Sales", data=train)
plt.title("Outlet Location Type vs Outlet Sales")
plt.xlabel("Outlet Location Type")
plt.ylabel("Outlet Sales")
plt.show()

# %%
sns.boxplot(x="Outlet_Type", y="Item_Outlet_Sales", data=train)
plt.xticks(rotation=90)
plt.title("Outlet Type vs Outlet Sales")
plt.xlabel("Outlet Type")
plt.ylabel("Outlet Sales")
plt.show()

# %%
sns.boxplot(x="Outlet_Size", y="Item_Outlet_Sales", data=train)
plt.title("Outlet Size vs Outlet Sales")
plt.xlabel("Outlet Size")
plt.ylabel("Outlet Sales")
plt.show()

# %% [markdown]
# # Missing Value

# %%
train.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#We can see that Item_Weight and Outlet_Size have missing values. We can fill them using mean and mode

# %%
train['Item_Weight'] = train['Item_Weight'].fillna(train['Item_Weight'].mean())
  
# replacing missing values in price column
# with median of that column
train.fillna(train['Outlet_Size'].mode()[0], inplace=True)

# %%
#Now, no missing values.
train.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# # Feature Preprocessing, Encoding, Scaling

# %%
train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
train['Outlet_Establishment_Year'] = le.fit_transform(train['Outlet_Establishment_Year'])

# %%
train['Item_Fat_Content'] = le.fit_transform(train['Item_Fat_Content'])

# %%
train['Outlet_Size'] = le.fit_transform(train['Outlet_Size'])

# %%
train['Outlet_Location_Type'] = le.fit_transform(train['Outlet_Location_Type'])

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
train['Item_Weight'] = scaler.fit_transform(train[['Item_Weight']])
train['Item_MRP'] = scaler.fit_transform(train[['Item_MRP']])

# %%
import category_encoders as ce

encoder = ce.BinaryEncoder(cols=['Item_Type'])
train = encoder.fit_transform(train)

# %%
encoder = ce.BinaryEncoder(cols=['Outlet_Type'])
train = encoder.fit_transform(train)

encoder = ce.BinaryEncoder(cols=['Outlet_Identifier'])
train = encoder.fit_transform(train)

# %%
train.drop(columns = ['Item_Identifier'], axis = 1, inplace = True)

# %%
train
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type_0  \
# 0        0.282525                 1         0.016047            0
# 1        0.081274                 2         0.019278            0
# 2        0.770765                 1         0.016760            0
# 3        0.871986                 2         0.000000            0
# 4        0.260494                 1         0.000000            0
# ...           ...               ...              ...          ...
# 8518     0.137541                 1         0.056783            0
# 8519     0.227746                 2         0.046982            0
# 8520     0.359929                 1         0.035186            0
# 8521     0.158083                 2         0.145221            0
# 8522     0.610003                 1         0.044878            0
#
#       Item_Type_1  Item_Type_2  Item_Type_3  Item_Type_4  Item_MRP  \
# 0               0            0            0            1  0.927507
# ...

# %% [markdown]
# # Training some models on this dataframe and saving them for testing

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from xgboost import XGBRegressor

# %%
X_train = train.iloc[:, :-1]
y_train = train.iloc[:, -1]

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
print('Linear Regression Training R^2:', lr.score(X_train, y_train))

# Fit a regularized linear regression model
lasso = Lasso(alpha=0.1)
lasso.fit(X_train, y_train)
print('Lasso Training R^2:', lasso.score(X_train, y_train))

# Fit a random forest model
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
print('Random Forest Training R^2:', rf.score(X_train, y_train))

#Fit an xgb Regressor model
xgb_model = xgb.XGBRegressor()
xgb_model.fit(X_train, y_train)
print('XGBoost R^2:', xgb_model.score(X_train, y_train))
# Out:
# Linear Regression Training R^2: 0.5635928449683876
# Lasso Training R^2: 0.5635737250390054
# C:\Users\Shehroz\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.834e+08, tolerance: 2.482e+06
#   model = cd_fast.enet_coordinate_descent(
# Random Forest Training R^2: 0.9386823900688452
# XGBoost R^2: 0.8336881229547263

# %%
import pickle

# save linear regression model
with open('linear_regression.pkl', 'wb') as file:
    pickle.dump(lr, file)
    
# save regularized linear regression model
with open('lasso.pkl', 'wb') as file:
    pickle.dump(lasso, file)
    
# save random forest model
with open('random_forest.pkl', 'wb') as file:
    pickle.dump(rf, file)
    
# save xgboost model
with open('xgboost.pkl', 'wb') as file:
    pickle.dump(xgb_model, file)
